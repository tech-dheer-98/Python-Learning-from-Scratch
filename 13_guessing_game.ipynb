# %% [markdown]
# # Guessing Game : 3 Cup Monte

# %%
# Importing Libraries 
from random import shuffle

# %%
# Shuffle a list 

mylist=[x for x in range(1,11)]

#Shuffling a list 
shuffle(mylist)
mylist
# Out:
# [2, 9, 5, 8, 7, 1, 4, 10, 3, 6]

# %%
# Creating a Function for Shuffling a List 

def shuffle_list(my_list):
    shuffle(my_list)
    return my_list

# %%
# Creating a Fucntion for Player to Guess 

def player_guess():

    guess=''
    while guess not in ['0','1','2']:
         guess=input("Pick a number 0,1,2 :")

    return int(guess)

# %%
# Creating a Check Guess fucntion to check if the guess is correct :

def check_guess(mylist,guess):
    if mylist[guess]=='O':
        print("Correct")
    else:
        print("Wrong Guess !")
        print(mylist)

# %%
# Setting up the Final Block- Code :


def shuffle_list(my_list):
    shuffle(my_list)
    return my_list

def player_guess():

    guess=''
    while guess not in ['0','1','2']:
         guess=input("Pick a number 0,1,2 :")

    return int(guess)

def check_guess(mylist,guess):
    if mylist[guess]=='O':
        print("Correct")
    else:
        print("Wrong Guess !")
        print(mylist)



# Initial List
mylist=[' ','O',' ']
# Shuffle List 
shuffled_mylist=shuffle_list(mylist)
# User Guess 
user_guess= player_guess()
# Check the Guess 
check_guess(shuffled_mylist,user_guess)
# Out:
# Wrong Guess !
# ['O', ' ', ' ']
