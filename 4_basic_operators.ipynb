# %% [markdown]
# # Comparison Operators
# 1) Equal (=)
# 2) Not Equal (!=)
# 3) Greater then (>)
# 4) Less then (<)
# 5) Greater then Equal to (>=)
# 6) Less then Equal to (<=)

# %%
2==1
# Out:
# False

# %%
"hello"=="bye"
# Out:
# False

# %%
2.0 ==2
# Out:
# True

# %% [markdown]
# # Logical Operators :
# 1) AND
# 2) OR
# 3) NOT

# %%
# AND Operator  

1<2 and 3<2
# Out:
# False

# %%
# OR Operator 
1<2 or 3<2
# Out:
# True

# %%
# Not Operator 
not (1<2 and 3<2)
# Out:
# True
