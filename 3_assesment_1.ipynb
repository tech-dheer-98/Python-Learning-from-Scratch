# %% [markdown]
# # Assesment Test 1 : Data Strcutures

# %% [markdown]
# #### Q1) Brief description of all the following Object Types and Data Structures
#
# 1) Numbers : Store Numerical Info and stored in 2 forms (Int,Float)
# 2) List : Ordered Sequence of Object (Mutable)
# 3) Tuple : Ordered Sequence of Object (Immutable)
# 4) String : Ordered Sequence of Characters
# 5) Dictionary : Key-Value pairs , that is Unordered
# 6) Boolean : True or False

# %% [markdown]
# #### Q2) Write an equation that uses multiplication, division, an exponent, addition, and subtraction that is equal to 100.25.
#
# Hint: This is just to test your memory of the basic arithmetic commands, work backwards from 100.25

# %%
(60+(10**2)/4*7) -134.75
# Out:
# 100.25

# %% [markdown]
# ###  Q3) Whats the Value of Expressions ?
#
# What is the value of the expression 4 * (6 + 5) = 44
#
# What is the value of the expression 4 * 6 + 5 =29
#
# What is the value of the expression 4 + 6 * 5 =34

# %% [markdown]
# ### Q4) What is the type of the result of the expression 3 + 1.5 + 4?
# Ans : 8.5 (So Floating Number )

# %% [markdown]
# ### Q5) What would you use to find a number’s square root, as well as its square?

# %%
# Square Root : 

print(f"This is the Square root of 100 :{100**0.5}")

# Square 

print(f"This is the Square of 10 :{10**2}")
# Out:
# This is the Square root of 100 :10.0
# This is the Square of 10 :100

# %% [markdown]
# ### Q6) Strings

# %%
# Given the string 'hello' give an index command that returns 'e'. Enter your code in the cell below:

s = 'hello'
# Print out 'e' using indexing

s[1]
# Out:
# 'e'

# %%
# Reverse the string 'hello' using slicing:

s ='hello'
# Reverse the string using slicing

s[::-1]
# Out:
# 'olleh'

# %%
# Given the string hello, give two methods of producing the letter 'o' using indexing.

s ='hello'
# Print out the 'o'

# Method 1:
print(f"This is Method 1 {s[-1]}")

# Method 2:
print(f"This is Method 2 {s[4]}")
# Out:
# This is Method 1 o
# This is Method 2 o

# %% [markdown]
# ### Q7) Lists
#
# #####  Build this list [0,0,0] two separate ways.

# %%
# Method 1 :
list1=[0]*3
list1
# Out:
# [0, 0, 0]

# %%
# Method 2 :
list2=[0,0,0]
list2
# Out:
# [0, 0, 0]

# %%
# Reassign 'hello' in this nested list to say 'goodbye' instead:

list3 = [1,2,[3,4,'hello']]

list3[2][2]='goodbye'

list3
# Out:
# [1, 2, [3, 4, 'goodbye']]

# %%
# Sort the list below:

list4 = [5,3,4,6,1]

#Method 1 
list4.sort()
print(f"This is method 1:{list4}")

# Method 2

sorted(list4)
print(f"This is method 2:{list4}")
# Out:
# This is method 1:[1, 3, 4, 5, 6]
# This is method 2:[1, 3, 4, 5, 6]

# %% [markdown]
# # Q8) Dictionaries

# %%
# Using keys and indexing, grab the 'hello' from the following dictionaries:

d = {'simple_key':'hello'}
# Grab 'hello'


d['simple_key']
# Out:
# 'hello'

# %%
# Getting a little tricker
d = {'k1':[{'nest_key':['this is deep',['hello']]}]}

#Grab hello

d['k1'][0]['nest_key'][1][0]
# Out:
# 'hello'

# %%
# This will be hard and annoying!
d = {'k1':[1,2,{'k2':['this is tricky',{'tough':[1,2,['hello']]}]}]}

d['k1'][2]['k2'][1]['tough'][2][0]
# Out:
# 'hello'

# %%
# Can you sort a dictionary ? Why or why not ?
# No , because normal dictionaries are mapping not a sequence

# %% [markdown]
# ###  Q9) Tuples
#
# What is the major difference between tuples and lists?
# - List Mutable , Tuple Immutable
#
# How do you create a tuple?
#
# - t=(1,"Dheer",5)

# %% [markdown]
# ### Q10) Sets
#
# What is unique about a set?
# - They dont allow duplicate values

# %%
# Use a set to find the unique values of the list below:

list5 = [1,2,2,33,4,4,11,22,3,3,2]

set(list5)
# Out:
# {1, 2, 3, 4, 11, 22, 33}

# %% [markdown]
# ### Q11) Booleans

# %%
# Answer before running cell
2 > 3
# Out:
# False

# %%
# Answer before running cell
3 == 2.0
# Out:
# False

# %%
# Answer before running cell
3.0 == 3
# Out:
# True

# %%
# Answer before running cell
4**0.5 != 2
# Out:
# False

# %%
# What is the boolean output of the cell block below?

# two nested lists
l_one = [1,2,[3,4]]
l_two = [1,2,{'k1':4}]

# True or False?
l_one[2][0] >= l_two[2]['k1']
# 3>=4
# Out:
# False
